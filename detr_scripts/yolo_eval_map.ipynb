# %%
import os
from ultralytics import YOLO
import json
import cv2
from tqdm.auto import tqdm
import torch
from torchmetrics.detection import MeanAveragePrecision

# %%
DATASET_DIR = "../hand-cursive-detr"
ANNOTATION_FILE_NAME = "_val_annotations_coco.json"
#HF_CACHE = "/home/ralvarez22/Documentos/llm_data/llm_cache"
DEVICE = "cuda"
CHECKPOINT = "../finetuned/yolo/Zani_V1/weights/last.pt"
CONFIDENCE_TRESHOLD = 0.5

# %%
DATASET_FILE = os.path.join(DATASET_DIR, ANNOTATION_FILE_NAME)

# %%
dataset_json = json.load(open(DATASET_FILE, "r"))

# %%
del dataset_json["info"]
del dataset_json["licenses"]
del dataset_json["categories"]

# %%
dataset_json.keys()
# Out:
# dict_keys(['images', 'annotations'])

# %%
images_with_boxes = []
for e in dataset_json["images"]:
    image_annotations = [
        x for x in dataset_json["annotations"] if x["image_id"] == e["id"]
    ]
    images_with_boxes.append(
        {"id": e["id"], "image": e["file_name"], "boxes": image_annotations}
    )

# %%
metric = MeanAveragePrecision(iou_type="bbox", class_metrics=True)

# %%
yolo_model = YOLO(CHECKPOINT)

# %%
def generate_bboxes(image):
    results = yolo_model.predict(image, conf=CONFIDENCE_TRESHOLD)[0].boxes
    return results.conf, results.xyxy, results.cls.int()

# %%
pred_data = []
tgt_data = []
for test_item in tqdm(images_with_boxes):
    boxes = torch.tensor([ [ x["bbox"][0], x["bbox"][1], x["bbox"][0] + x["bbox"][2], x["bbox"][1] + x["bbox"][3] ]  for x in test_item["boxes"]], device=DEVICE)
    cats = torch.tensor([x["category_id"] for x in test_item["boxes"]], device=DEVICE)
    input_image = os.path.join(DATASET_DIR, test_item["image"])
    image_pixels = cv2.imread(input_image)
    scores, pred_boxes, labels = generate_bboxes(image_pixels)
    
    tgt_data.append({
        "boxes": boxes,
        "labels": cats
    })
    pred_data.append({
        "boxes": pred_boxes,
        "scores": scores,
        "labels": labels
    })
# Out:
#   0%|          | 0/479 [00:00<?, ?it/s]
# 0: 640x512 53 words, 47.6ms
# Speed: 5.4ms preprocess, 47.6ms inference, 105.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.8ms
# Speed: 3.0ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 14.0ms
# Speed: 3.5ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.8ms
# Speed: 3.7ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.4ms
# Speed: 2.6ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 13.5ms
# Speed: 3.2ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 13.0ms
# Speed: 5.1ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.3ms
# Speed: 3.7ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.3ms
# Speed: 2.9ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.8ms
# Speed: 3.3ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 8.8ms
# Speed: 3.4ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.5ms
# Speed: 2.5ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.2ms
# Speed: 2.1ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.5ms
# Speed: 3.4ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 13.4ms
# Speed: 3.9ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 11.7ms
# Speed: 5.1ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 13.4ms
# Speed: 4.5ms preprocess, 13.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.9ms
# Speed: 3.0ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 words, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.9ms
# Speed: 3.5ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.2ms
# Speed: 2.4ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 13.6ms
# Speed: 3.4ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 words, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 13.8ms
# Speed: 3.6ms preprocess, 13.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 12.4ms
# Speed: 2.6ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.9ms
# Speed: 2.3ms preprocess, 11.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.6ms
# Speed: 3.2ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 8.9ms
# Speed: 2.6ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.5ms
# Speed: 2.1ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 8.4ms
# Speed: 2.7ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.8ms
# Speed: 2.6ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 45 words, 10.0ms
# Speed: 3.9ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 10.5ms
# Speed: 3.8ms preprocess, 10.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 25 words, 11.7ms
# Speed: 2.6ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.5ms
# Speed: 5.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.6ms
# Speed: 2.0ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 10.7ms
# Speed: 3.6ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 8.7ms
# Speed: 2.6ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.3ms
# Speed: 3.0ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.4ms
# Speed: 2.6ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.4ms
# Speed: 2.1ms preprocess, 11.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 11.1ms
# Speed: 2.2ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.2ms
# Speed: 3.5ms preprocess, 10.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.1ms
# Speed: 3.3ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.7ms
# Speed: 2.8ms preprocess, 8.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.9ms
# Speed: 2.8ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.5ms
# Speed: 2.2ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.2ms
# Speed: 3.2ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 13.8ms
# Speed: 3.2ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 12.4ms
# Speed: 4.2ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.4ms
# Speed: 2.5ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 46 words, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 8.0ms
# Speed: 3.1ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 13.4ms
# Speed: 3.8ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 11.4ms
# Speed: 2.0ms preprocess, 11.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.0ms
# Speed: 3.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 15.6ms
# Speed: 4.1ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 15.3ms
# Speed: 3.4ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.9ms
# Speed: 4.5ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 12.7ms
# Speed: 2.8ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.9ms
# Speed: 3.7ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.7ms
# Speed: 3.8ms preprocess, 11.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.3ms
# Speed: 2.1ms preprocess, 12.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.4ms
# Speed: 4.2ms preprocess, 10.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.1ms
# Speed: 2.1ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 words, 9.5ms
# Speed: 3.8ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 13.7ms
# Speed: 4.2ms preprocess, 13.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.3ms
# Speed: 3.4ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.5ms
# Speed: 2.4ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 11.2ms
# Speed: 6.2ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 11.2ms
# Speed: 2.6ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 9.0ms
# Speed: 3.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 words, 9.5ms
# Speed: 2.3ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.2ms
# Speed: 3.5ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 15.8ms
# Speed: 5.6ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.9ms
# Speed: 3.4ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 14.2ms
# Speed: 3.2ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.1ms
# Speed: 4.4ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.8ms
# Speed: 2.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 14.5ms
# Speed: 4.1ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.0ms
# Speed: 3.9ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.7ms
# Speed: 2.7ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.7ms
# Speed: 5.0ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 9.5ms
# Speed: 3.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 10.3ms
# Speed: 2.2ms preprocess, 10.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 43 words, 9.9ms
# Speed: 3.4ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 13.8ms
# Speed: 2.4ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 13.7ms
# Speed: 3.9ms preprocess, 13.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.6ms
# Speed: 2.6ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.0ms
# Speed: 2.7ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.9ms
# Speed: 3.0ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.3ms
# Speed: 3.1ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 9.1ms
# Speed: 4.0ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.7ms
# Speed: 2.9ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 12.2ms
# Speed: 2.3ms preprocess, 12.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.4ms
# Speed: 2.5ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.3ms
# Speed: 3.2ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 13.2ms
# Speed: 4.3ms preprocess, 13.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.4ms
# Speed: 3.6ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.9ms
# Speed: 2.3ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.8ms
# Speed: 3.3ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.9ms
# Speed: 2.4ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 10.7ms
# Speed: 3.2ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 11.5ms
# Speed: 3.3ms preprocess, 11.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 10.8ms
# Speed: 3.4ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 words, 9.4ms
# Speed: 4.6ms preprocess, 9.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 12.8ms
# Speed: 2.3ms preprocess, 12.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 45 words, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 13.0ms
# Speed: 2.4ms preprocess, 13.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 13.0ms
# Speed: 4.3ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 words, 10.5ms
# Speed: 2.6ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.6ms
# Speed: 2.1ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 words, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.8ms
# Speed: 3.1ms preprocess, 10.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.9ms
# Speed: 4.6ms preprocess, 10.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 38 words, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 13.6ms
# Speed: 2.1ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 12.3ms
# Speed: 3.6ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 12.7ms
# Speed: 3.7ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.4ms
# Speed: 3.9ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.7ms
# Speed: 2.5ms preprocess, 9.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.3ms
# Speed: 3.5ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.3ms
# Speed: 3.5ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.8ms
# Speed: 2.1ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.3ms
# Speed: 2.2ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 45 words, 10.9ms
# Speed: 5.4ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.1ms
# Speed: 2.7ms preprocess, 9.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 words, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 13.9ms
# Speed: 2.8ms preprocess, 13.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.2ms
# Speed: 3.1ms preprocess, 11.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 13.2ms
# Speed: 2.7ms preprocess, 13.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 10.7ms
# Speed: 2.4ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 11.6ms
# Speed: 2.6ms preprocess, 11.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.9ms
# Speed: 2.9ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.2ms
# Speed: 2.9ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 13.3ms
# Speed: 3.7ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.0ms
# Speed: 2.5ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.1ms
# Speed: 3.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 11.2ms
# Speed: 2.5ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 10.0ms
# Speed: 2.4ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 35 words, 12.4ms
# Speed: 3.0ms preprocess, 12.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 8.2ms
# Speed: 2.4ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 48 words, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 16.4ms
# Speed: 2.3ms preprocess, 16.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.3ms
# Speed: 2.7ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.4ms
# Speed: 3.3ms preprocess, 14.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 8.6ms
# Speed: 2.8ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.7ms
# Speed: 2.1ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 8.7ms
# Speed: 2.7ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.4ms
# Speed: 2.7ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.7ms
# Speed: 2.3ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 10.5ms
# Speed: 2.5ms preprocess, 10.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.1ms
# Speed: 3.4ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.5ms
# Speed: 3.2ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.3ms
# Speed: 3.5ms preprocess, 12.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 12.6ms
# Speed: 3.3ms preprocess, 12.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 11.6ms
# Speed: 3.2ms preprocess, 11.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 9.7ms
# Speed: 3.1ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 10.1ms
# Speed: 2.6ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 12.1ms
# Speed: 4.7ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 13.1ms
# Speed: 2.3ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.5ms
# Speed: 2.1ms preprocess, 11.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.8ms
# Speed: 2.7ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 14.1ms
# Speed: 3.5ms preprocess, 14.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 35 words, 10.1ms
# Speed: 3.6ms preprocess, 10.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 7.9ms
# Speed: 2.4ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 9.5ms
# Speed: 3.1ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.6ms
# Speed: 2.3ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 11.3ms
# Speed: 3.3ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 10.3ms
# Speed: 3.6ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 9.4ms
# Speed: 2.1ms preprocess, 9.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 13.0ms
# Speed: 3.3ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 12.0ms
# Speed: 2.1ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.5ms
# Speed: 3.4ms preprocess, 8.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 43 words, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.1ms
# Speed: 2.4ms preprocess, 10.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 8.5ms
# Speed: 2.7ms preprocess, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 61 words, 13.9ms
# Speed: 4.0ms preprocess, 13.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.6ms
# Speed: 3.5ms preprocess, 14.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.9ms
# Speed: 2.8ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.6ms
# Speed: 2.1ms preprocess, 9.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.4ms
# Speed: 3.3ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.4ms
# Speed: 2.1ms preprocess, 10.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.6ms
# Speed: 2.1ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 11.6ms
# Speed: 2.4ms preprocess, 11.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.8ms
# Speed: 2.3ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 49 words, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 67 words, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 43 words, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 13.3ms
# Speed: 4.6ms preprocess, 13.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 12.3ms
# Speed: 3.9ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 8.8ms
# Speed: 2.4ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 66 words, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 12.0ms
# Speed: 2.9ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 62 words, 9.6ms
# Speed: 2.3ms preprocess, 9.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.4ms
# Speed: 2.6ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.3ms
# Speed: 2.7ms preprocess, 10.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.6ms
# Speed: 2.4ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.8ms
# Speed: 3.1ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 14.4ms
# Speed: 3.2ms preprocess, 14.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 13.4ms
# Speed: 3.6ms preprocess, 13.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.0ms
# Speed: 3.2ms preprocess, 10.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.8ms
# Speed: 3.2ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 55 words, 9.5ms
# Speed: 2.4ms preprocess, 9.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.6ms
# Speed: 3.0ms preprocess, 14.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 12.0ms
# Speed: 3.4ms preprocess, 12.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.3ms
# Speed: 2.2ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 57 words, 9.0ms
# Speed: 3.3ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 58 words, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 31 words, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.8ms
# Speed: 2.4ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 44 words, 10.6ms
# Speed: 2.4ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.3ms
# Speed: 2.3ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 10.0ms
# Speed: 2.2ms preprocess, 10.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 12.3ms
# Speed: 2.8ms preprocess, 12.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 12.1ms
# Speed: 2.3ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 47 words, 13.4ms
# Speed: 3.8ms preprocess, 13.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 50 words, 12.9ms
# Speed: 3.1ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 14.9ms
# Speed: 2.4ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 12.1ms
# Speed: 2.4ms preprocess, 12.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 10.7ms
# Speed: 2.2ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 51 words, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 63 words, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 12.2ms
# Speed: 3.7ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 53 words, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 9.8ms
# Speed: 4.2ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 10.6ms
# Speed: 3.4ms preprocess, 10.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 10.2ms
# Speed: 2.3ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 8.8ms
# Speed: 2.2ms preprocess, 8.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 56 words, 11.1ms
# Speed: 2.3ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 54 words, 10.1ms
# Speed: 2.3ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 64 words, 13.1ms
# Speed: 3.6ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 59 words, 8.8ms
# Speed: 4.1ms preprocess, 8.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 52 words, 9.9ms
# Speed: 2.3ms preprocess, 9.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.1ms
# Speed: 3.2ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 65 words, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 640x512 60 words, 9.3ms
# Speed: 2.1ms preprocess, 9.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)

# %%
metric.update(pred_data, tgt_data)

# %%
metric.compute()
# Out:
# {'map': tensor(0.6210),
#  'map_50': tensor(0.9735),
#  'map_75': tensor(0.6745),
#  'map_small': tensor(0.),
#  'map_medium': tensor(0.5585),
#  'map_large': tensor(0.6547),
#  'mar_1': tensor(0.0138),
#  'mar_10': tensor(0.1352),
#  'mar_100': tensor(0.7224),
#  'mar_small': tensor(0.),
#  'mar_medium': tensor(0.6773),
#  'mar_large': tensor(0.7515),
#  'map_per_class': tensor(0.6210),
#  'mar_100_per_class': tensor(0.7224),
#  'classes': tensor(1, dtype=torch.int32)}
